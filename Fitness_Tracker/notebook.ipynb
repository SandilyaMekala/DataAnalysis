# %% [markdown]
# # AI Python Zero-to-Hero: Build Your Own Fitness Tracker
#
# In this code-along, we'll learn how to combine AI, data analysis, and Python to explore and visualize fitness data.
#
# The data is available in this workbook as `fitness_data.csv`. It is synthetic data consisting of the following columns:
#
# ### Data Dictionary
#
# | Column Name | Description | Additional Context |
# |------------|-------------|-------------------|
# | `date` | The specific day of data recording | Allows tracking changes and patterns over the 185-day period |
# | `steps` | Total daily step count | The common goal of 10,000 steps serves as a reference point for daily activity level assessment |
# | `weight` | Body weight measurement (in kg) | Tracked daily to monitor body mass changes over time |
# | `resting_heart_rate` | Heart beats per minute while at complete rest | Lower values typically indicate better cardiovascular fitness |
# | `sleep_hours` | Total daily sleep duration | Includes all sleep phases; adults typically need 7-9 hours per night for optimal health |
# | `active_minutes` | Total time spent in physical activity | Encompasses all activity intensities throughout the day |
# | `total_calories_burned` | Total daily energy expenditure | Combines both resting metabolic rate and activity-based calorie burn |
# | `fat_burn_minutes` | Time in 50-69% of max heart rate zone | Lower intensity zone optimal for building base endurance and metabolizing fat |
# | `cardio_minutes` | Time in 70-84% of max heart rate zone | Moderate to high intensity zone that improves cardiovascular capacity |
# | `peak_minutes` | Time in 85%+ of max heart rate zone | Highest intensity zone, typically reached during interval training or sprints |
# | `workout_type` | Category of exercise performed | Helps analyze the distribution and effectiveness of different activities |
# | `workout_duration` | Length of exercise session in minutes | Used to analyze exercise patterns and time commitment |
# | `workout_calories` | Energy expended during workout | Specifically tracks calories burned during structured exercise sessions |
# | `workout_avg_hr` | Mean heart rate during exercise | Indicates the overall intensity of the workout session |
# | `workout_max_hr` | Highest heart rate during exercise | Shows the point of maximum exertion during the workout |
#
# Most fitness tracking apps and devices contain variations of the above columns, and allow you to export the data for your own analysis.
#
# Let's dive in!

# %% [markdown]
# ## Task 0: Setup
#
# We're going to use `pandas` for data analysis and `plotly.express` for interactive data visualization.

# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Task 1: Reading in the data 📖
#
# Let's read in and display the `fitness_data.csv` file using `pandas`.

# %%
# Read in the dataset "fitness_data.csv"
fd = pd.read_csv('fitness_data.csv')

# Display the data
print(fd)
# Out:
#          date     weight  ...  cardio_minutes  peak_minutes
# 0      7/1/24  75.248357  ...            19.0          13.0
# 1      7/2/24  74.914564  ...            19.0          13.0
# 2      7/3/24  75.140000  ...            26.0          17.0
# 3      7/4/24  75.200000  ...            33.0          22.0
# 4      7/5/24  75.270000  ...            23.0          15.0
# ..        ...        ...  ...             ...           ...
# 180  12/28/24  77.690000  ...            21.0          14.0
# 181  12/29/24  77.610000  ...            26.0          17.0
# 182  12/30/24  77.490000  ...            26.0          17.0
# 183  12/31/24  77.550000  ...            27.0          18.0
# 184    1/1/25  78.170000  ...            23.0          15.0
#
# [185 rows x 15 columns]

# %% [markdown]
# ## Task 2: Checking for missing values 🔎
#
# Now that we've read in the data, let's check whether it has any missing values.

# %%
# Does the data have any missing values?
fd.isnull().sum()
# Out:
# date                     0
# weight                   6
# steps                    6
# resting_heart_rate       6
# sleep_hours              6
# active_minutes           6
# total_calories_burned    6
# workout_type             6
# workout_duration         6
# workout_calories         6
# workout_avg_hr           6
# workout_max_hr           6
# fat_burn_minutes         6
# cardio_minutes           6
# peak_minutes             6
# dtype: int64

# %%
# Which rows have missing values?
rows = fd[fd.isnull().any(axis=1)]
print(rows)
# Out:
#          date  weight  steps  ...  fat_burn_minutes  cardio_minutes  peak_minutes
# 150  11/28/24     NaN    NaN  ...               NaN             NaN           NaN
# 151  11/29/24     NaN    NaN  ...               NaN             NaN           NaN
# 152  11/30/24     NaN    NaN  ...               NaN             NaN           NaN
# 176  12/24/24     NaN    NaN  ...               NaN             NaN           NaN
# 177  12/25/24     NaN    NaN  ...               NaN             NaN           NaN
# 178  12/26/24     NaN    NaN  ...               NaN             NaN           NaN
#
# [6 rows x 15 columns]

# %% [markdown]
# ## Task 3: Exploring the data 🔎
#
# Let's start exploring our data by calculating summary statistics and confirming that our columns are of the correct data type.

# %%
# What are the summary statistics?
print(fd.describe())
# Out:
#            weight         steps  ...  cardio_minutes  peak_minutes
# count  179.000000    179.000000  ...      179.000000    179.000000
# mean    74.838842   8476.927374  ...       25.100559     16.636872
# std      1.817232   2350.241475  ...        6.703257      4.442768
# min     71.110000   3207.000000  ...        9.000000      6.000000
# 25%     73.130000   6823.000000  ...       21.000000     14.000000
# 50%     75.269587   8524.000000  ...       25.000000     16.000000
# 75%     76.530000   9704.500000  ...       29.000000     19.000000
# max     78.170000  15724.000000  ...       47.000000     31.000000
#
# [8 rows x 13 columns]

# %%
# Check the data types of each column
print(fd.dtypes)
# Out:
# date                      object
# weight                   float64
# steps                    float64
# resting_heart_rate       float64
# sleep_hours              float64
# active_minutes           float64
# total_calories_burned    float64
# workout_type              object
# workout_duration         float64
# workout_calories         float64
# workout_avg_hr           float64
# workout_max_hr           float64
# fat_burn_minutes         float64
# cardio_minutes           float64
# peak_minutes             float64
# dtype: object

# %%
# Convert the date column to a datetime format
fd['date'] = pd.to_datetime(fd['date'])
print(fd.dtypes)
# Out:
# date                     datetime64[ns]
# weight                          float64
# steps                           float64
# resting_heart_rate              float64
# sleep_hours                     float64
# active_minutes                  float64
# total_calories_burned           float64
# workout_type                     object
# workout_duration                float64
# workout_calories                float64
# workout_avg_hr                  float64
# workout_max_hr                  float64
# fat_burn_minutes                float64
# cardio_minutes                  float64
# peak_minutes                    float64
# dtype: object

# %% [markdown]
# ## Task 4: Creating useful new columns
#
# Sometimes we might want to rename columns with more descriptive names to be easier to interpret, or create new columns to measure things we are interested in.

# %%
# Rename 'weight" and 'workout_duration' to have more descriptive names
fd.rename(columns={'weight': 'weight_kg', 'workout_duration': 'workout_duration_mins'}, inplace=True)
print(fd.columns)
# Out:
# Index(['date', 'weight_kg', 'steps', 'resting_heart_rate', 'sleep_hours',
#        'active_minutes', 'total_calories_burned', 'workout_type',
#        'workout_duration_mins', 'workout_calories', 'workout_avg_hr',
#        'workout_max_hr', 'fat_burn_minutes', 'cardio_minutes', 'peak_minutes'],
#       dtype='object')

# %%
# Add a new column 'weight_lbs' converting weight from kilograms to pounds (1 kg = 2.20462 lbs)
fd['weight_lbs'] = fd['weight_kg'] * 2.20462
print(fd.head())
# Out:
#         date  weight_kg    steps  ...  cardio_minutes  peak_minutes  weight_lbs
# 0 2024-07-01  75.248357   6829.0  ...            19.0          13.0  165.894033
# 1 2024-07-02  74.914564   7741.0  ...            19.0          13.0  165.158145
# 2 2024-07-03  75.140000   8227.0  ...            26.0          17.0  165.655147
# 3 2024-07-04  75.200000  13262.0  ...            33.0          22.0  165.787424
# 4 2024-07-05  75.270000   9377.0  ...            23.0          15.0  165.941747
#
# [5 rows x 16 columns]

# %%
# Add a column to indicate the day of the week
fd['day_of_week'] = fd['date'].dt.day_name()
#print(fd['date'].dt.month_name())
# Add a column to indicate weekends or weekends
fd['is_weekend'] = fd['day_of_week'].isin(['Saturday', 'Sunday'])

# Display the data
print(fd.head())
# Out:
#         date  weight_kg    steps  ...  weight_lbs  day_of_week  is_weekend
# 0 2024-07-01  75.248357   6829.0  ...  165.894033       Monday       False
# 1 2024-07-02  74.914564   7741.0  ...  165.158145      Tuesday       False
# 2 2024-07-03  75.140000   8227.0  ...  165.655147    Wednesday       False
# 3 2024-07-04  75.200000  13262.0  ...  165.787424     Thursday       False
# 4 2024-07-05  75.270000   9377.0  ...  165.941747       Friday       False
#
# [5 rows x 18 columns]

# %%
# Add a new column 'sleep_debt' that calculates the difference between sleep_hours and a target of 7.5 hours
fd['sleep_debt'] = fd['sleep_hours'] - 7.5
print(fd.head())
# Out:
#         date  weight_kg    steps  ...  day_of_week  is_weekend  sleep_debt
# 0 2024-07-01  75.248357   6829.0  ...       Monday       False       -0.47
# 1 2024-07-02  74.914564   7741.0  ...      Tuesday       False        0.35
# 2 2024-07-03  75.140000   8227.0  ...    Wednesday       False        0.03
# 3 2024-07-04  75.200000  13262.0  ...     Thursday       False       -2.87
# 4 2024-07-05  75.270000   9377.0  ...       Friday       False       -2.12
#
# [5 rows x 19 columns]

# %%
# Create a new column that calculates the cumulative sleep debt
fd['cum_sleep_debt'] = fd['sleep_debt'].cumsum()
print(fd.head())
# Out:
#         date  weight_kg    steps  ...  is_weekend  sleep_debt  cum_sleep_debt
# 0 2024-07-01  75.248357   6829.0  ...       False       -0.47           -0.47
# 1 2024-07-02  74.914564   7741.0  ...       False        0.35           -0.12
# 2 2024-07-03  75.140000   8227.0  ...       False        0.03           -0.09
# 3 2024-07-04  75.200000  13262.0  ...       False       -2.87           -2.96
# 4 2024-07-05  75.270000   9377.0  ...       False       -2.12           -5.08
#
# [5 rows x 20 columns]

# %% [markdown]
# ## Task 5: Visualizing trends across single variables 📈
#
# Let's visualize the distributions and trends of different columns in our data.

# %%
# Create a plotly histogram of the number of steps

fig = px.histogram(fd, x='steps', nbins=30, title='Distribution of Steps')
fig.update_layout(xaxis_title='Number of Steps', yaxis_title='Frequency', bargap=0.1)
fig.show()

# %%
# Create a line chart for the number of steps over time
fig = px.line(fd, x='date', y='steps', title='Number of steps over Time')

weekend = fd[fd['is_weekend']]
fig.add_scatter(x=weekend['date'], y=weekend['steps'], mode='markers', name='weekend', marker=dict(color='red', size=10))

fig.update_layout(xaxis_title='Time', yaxis_title='Number of Steps')
# Display the line chart
fig.show()

# %%
# Visualize the distribution of calories burned
fig = px.bar(fd, y='total_calories_burned', x='date', title='Distribution of calories burned')
fig.update_layout(xaxis_title='Time', yaxis_title='Calories burned', bargap=0.1)
fig.show()

# %%
# Create a line chart for the number of calories burned over time
fig = px.line(fd, y='total_calories_burned', x='date', title='Number of calories burned over time')

weekend = fd[fd['is_weekend']]
fig.add_scatter(x=weekend['date'], y=weekend['total_calories_burned'], mode='markers', name='Weekend', marker=dict(color= 'Green', size= 10))
#fig.add_scatter(x=weekend['date'], y=weekend['total_calories_burned'], mode='markers', name='Weekend', marker={'color': 'Green', 'size': 10})

fig.update_layout(xaxis_title='Time', yaxis_title='Number of calories burned')

# Display the line chart
fig.show()

# %%
# Visualize weight trend over time
fig = px.line(fd, y='weight_kg', x='date', title='weight trend over time')
fig.update_layout(xaxis_title='Time', yaxis_title='Weight in Kgs', bargap=0.1)
fig.show()

# %% [markdown]
# ## Task 6: Visualizing trends across multiple variables 📊

# %%
# Create a line chart visualizing sleep metrics over time
fig = px.line(fd, y='sleep_hours', x='date', title='Sleep metrics over time', labels={'date': 'Time', 'sleep_hours': 'Sleep Hours'})

fig.show()

# %%
# Create a box plot for sleep hours comparing weekdays and weekends
fig = px.box(fd, x='is_weekend', y='sleep_hours', title='Sleep hours comparing weekdays and week hours', labels={'is_weekend': 'Weekend', 'sleep_hours': 'Sleep hours'})

#fig = px.box(fd, x='is_weekend', y='sleep_hours', title='Sleep hours comparing weekdays and week hours', labels=dict(is_weekend= 'Weekend', sleep_hours= 'Sleep hours'))

fig.show()

# %%
# Visualize average sleep by day of week
avg_sleep_by_day = fd.groupby('day_of_week', as_index=False)['sleep_hours'].mean()
fig = px.bar(avg_sleep_by_day, x='day_of_week', y='sleep_hours', 
             title='Average Sleep Hours by Day of Week',
             labels={'day_of_week': 'Day of Week', 'sleep_hours': 'Average Sleep Hours'})
fig.show()

# %%
# Visualize number of steps vs. calories burned
fig = px.scatter(fd, x='steps', y='total_calories_burned', title='Number of Steps vs. Calories Burned', labels={'steps': 'Number of Steps', 'total_calories_burned': 'Total Calories Burned'}, trendline='ols')
fig.update_traces(marker=dict(color='green', size=10, opacity=0.7))
fig.show()

# %%
# How many different workout types are in the dataset?
print(fd['workout_type'].value_counts(sort=True, normalize=False))

print(fd['workout_type'].nunique())
# Out:
# workout_type
# Running              51
# Yoga                 42
# Strength Training    41
# HIIT                 32
# Rest                 13
# Name: count, dtype: int64
# 5

# %%
# Visualize trends across workout types
fig = px.scatter(fd, x='date', y='workout_duration_mins', color='workout_type', title='Trends in Workout Duration Across Workout Types Over Time', labels={'date': 'Date', 'workout_duration_mins': 'Workout Duration (mins)', 'workout_type': 'Workout Type'}, trendline='ols')

fig.show()
